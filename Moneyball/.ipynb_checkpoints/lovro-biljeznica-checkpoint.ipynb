# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math 
import csv
import os 
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
DATA_LOCATION = "data/main_players.csv"
FIRST_ATTRIBUTE = "LS"
SECOND_ATTRIBUTE = "ST"
treci="RS"
cetvrti="LW"
peti="LF"
sest="CF"
sedam="RF"
osam="RW"
devet="LAM"
deset="CAM"
jed="RAM"
dva="LM"
tri="CM"
cet="RCM"
pet="RM"
ses="LWB"
sed="LDM"
osa="CDM"
dev="RDM"
dvades="RWB"
djed="LB"
ddva="LCB"
dtri="CB"
dcet="RCB"
dpet="RB"
dses="LCM"
dosa="pozicija"
datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE, treci,cetvrti,peti,peti,sest,sedam,osam,devet,deset,jed,dva,tri,cet,pet,ses,sed,osa,dev,dvades,djed,ddva,dtri,dcet,dpet,dses,dosa]]
K = data1.values
print(data1.head())
#split dataset in features and target variable
feature_cols = [FIRST_ATTRIBUTE, SECOND_ATTRIBUTE, treci,cetvrti,peti,peti,sest,sedam,osam,devet,deset,jed,dva,tri,cet,pet,ses,sed,osa,dev,dvades,djed,ddva,dtri,dcet,dpet,dses]
X = datas[feature_cols] # Features
y = datas.pozicija # Target variable
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['N','V','B'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# /home/lovro/.local/lib/python3.6/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
#    LS  ST  RS  LW  LF  LF  CF  RF  RW  LAM  ...  CDM  RDM  RWB  LB  LCB  CB  \
# 0  88  88  88  92  93  93  93  93  92   93  ...   61   61   64  59   47  47
# 1  84  84  84  89  89  89  89  89  89   89  ...   60   60   65  60   47  47
# 2  77  77  77  85  84  84  84  84  85   87  ...   81   81   82  79   71  71
# 3  87  87  87  86  87  87  87  87  86   85  ...   68   68   69  66   63  63
# 4  73  73  73  70  71  71  71  71  70   71  ...   84   84   81  84   87  87
#
#    RCB  RB  LCM  pozicija
# 0   47  59   84         N
# 1   47  60   81         N
# 2   71  79   88         V
# 3   63  66   79         N
# 4   87  84   75         B
#
# [5 rows x 28 columns]
# Accuracy: 0.7924430641821946
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-edcff2625a66> in <module>
#      70                 filled=True, rounded=True,
#      71                 special_characters=True,feature_names = feature_cols,class_names=['N','V','B'])
# ---> 72 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#      73 graph.write_png('diabetes.png')
#      74 Image(graph.create_png())
#
# ~/.local/lib/python3.6/site-packages/pydotplus/graphviz.py in graph_from_dot_data(data)
#     300     """
#     301
# --> 302     return parser.parse_dot_data(data)
#     303
#     304
#
# ~/.local/lib/python3.6/site-packages/pydotplus/parser.py in parse_dot_data(data)
#     556             graphparser.parseWithTabs()
#     557
# --> 558         tokens = graphparser.parseString(data)
#     559
#     560         if len(tokens) == 1:
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1802             instring = instring.expandtabs()
#    1803         try:
# -> 1804             loc, tokens = self._parse( instring, 0 )
#    1805             if parseAll:
#    1806                 loc = self.preParse( instring, loc )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1546             if self.mayIndexError or preloc >= len(instring):
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#    1550                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4289         if check_ender:
#    4290             try_not_ender(instring, loc)
# -> 4291         loc, tokens = self_expr_parse( instring, loc, doActions, callPreParse=False )
#    4292         try:
#    4293             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1546             if self.mayIndexError or preloc >= len(instring):
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#    1550                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3720                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3721             else:
# -> 3722                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3723             if exprtokens or exprtokens.haskeys():
#    3724                 resultlist += exprtokens
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1546             if self.mayIndexError or preloc >= len(instring):
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#    1550                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4065     def parseImpl( self, instring, loc, doActions=True ):
#    4066         if self.expr is not None:
# -> 4067             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4068         else:
#    4069             raise ParseException("",loc,self.errmsg,self)
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1546             if self.mayIndexError or preloc >= len(instring):
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#    1550                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3720                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3721             else:
# -> 3722                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3723             if exprtokens or exprtokens.haskeys():
#    3724                 resultlist += exprtokens
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1546             if self.mayIndexError or preloc >= len(instring):
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#    1550                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4425     def parseImpl( self, instring, loc, doActions=True ):
#    4426         try:
# -> 4427             loc, tokens = self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4428         except (ParseException,IndexError):
#    4429             if self.defaultValue is not _optionalNotMatched:
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1546             if self.mayIndexError or preloc >= len(instring):
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#    1550                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4065     def parseImpl( self, instring, loc, doActions=True ):
#    4066         if self.expr is not None:
# -> 4067             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    4068         else:
#    4069             raise ParseException("",loc,self.errmsg,self)
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1546             if self.mayIndexError or preloc >= len(instring):
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#    1550                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4299                 else:
#    4300                     preloc = loc
# -> 4301                 loc, tmptokens = self_expr_parse( instring, preloc, doActions )
#    4302                 if tmptokens or tmptokens.haskeys():
#    4303                     tokens += tmptokens
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1546             if self.mayIndexError or preloc >= len(instring):
#    1547                 try:
# -> 1548                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#    1549                 except IndexError:
#    1550                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3720                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    3721             else:
# -> 3722                 loc, exprtokens = e._parse( instring, loc, doActions )
#    3723             if exprtokens or exprtokens.haskeys():
#    3724                 resultlist += exprtokens
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1707                 ParserElement.packrat_cache_stats[MISS] += 1
#    1708                 try:
# -> 1709                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1710                 except ParseBaseException as pe:
#    1711                     # cache a copy of the exception, without the traceback
#
# ~/.local/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1554         tokens = self.postParse( instring, loc, tokens )
#    1555
# -> 1556         retTokens = ParseResults( tokens, self.resultsName, asList=self.saveAsList, modal=self.modalResults )
#    1557         if self.parseAction and (doActions or self.callDuringTry):
#    1558             if debugging:
#
# KeyboardInterrupt:

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
pima = pd.read_csv("diabetes.csv", header=None, names=col_names)

# %%
pima.head()

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] # Features
y = pima.label # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(palette="dark")

g=sns.pairplot(PCA_atrF_df, x_vars={'CP1','CP3','ModCP2'}, hue= 'Hemis',
               y_vars={'Media','SD','DesMax', 'DesMin' })

def corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.65, .03), xycoords=ax.transAxes)

g.map(corrfunc)      
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5de88bb13112> in <module>
#       3 sns.set(palette="dark")
#       4
# ----> 5 g=sns.pairplot(PCA_atrF_df, x_vars={'CP1','CP3','ModCP2'}, hue= 'Hemis',
#       6                y_vars={'Media','SD','DesMax', 'DesMin' })
#       7
#
# NameError: name 'PCA_atrF_df' is not defined

# %%
# IMPORTING REQUIRED LIBRARIES & ASSIGNING ALIASES:
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading Pandas DataFrame:
df = pd.read_csv('data/main_players.csv', encoding='utf-8')

# %%
df.head(10)
# Out:
#    Unnamed: 0      ID            Name  Age  \
# 0           0  158023        L. Messi   31
# 1           1  190871       Neymar Jr   26
# 2           2  177003       L. Modrić   32
# 3           3  176580       L. Suárez   31
# 4           4  155862    Sergio Ramos   32
# 5           5  188545  R. Lewandowski   29
# 6           6  182493        D. Godín   32
# 7           7  168542     David Silva   32
# 8           8  215914        N. Kanté   27
# 9           9  211110       P. Dybala   24
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 2  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 3  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 4  https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 5  https://cdn.sofifa.org/players/4/19/188545.png      Poland
# 6  https://cdn.sofifa.org/players/4/19/182493.png     Uruguay
# 7  https://cdn.sofifa.org/players/4/19/168542.png       Spain
# 8  https://cdn.sofifa.org/players/4/19/215914.png      France
# 9  https://cdn.sofifa.org/players/4/19/211110.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/54.png       92         93
# 2  https://cdn.sofifa.org/flags/10.png       91         91
# 3  https://cdn.sofifa.org/flags/60.png       91         91
# 4  https://cdn.sofifa.org/flags/45.png       91         91
# 5  https://cdn.sofifa.org/flags/37.png       90         90
# 6  https://cdn.sofifa.org/flags/60.png       90         90
# 7  https://cdn.sofifa.org/flags/45.png       90         90
# 8  https://cdn.sofifa.org/flags/18.png       89         90
# 9  https://cdn.sofifa.org/flags/52.png       89         94
#
#                   Club  ... Marking StandingTackle SlidingTackle  GKDiving  \
# 0         FC Barcelona  ...      33             28            26         6
# 1  Paris Saint-Germain  ...      27             24            33         9
# 2          Real Madrid  ...      60             76            73        13
# 3         FC Barcelona  ...      62             45            38        27
# 4          Real Madrid  ...      87             92            91        11
# 5    FC Bayern München  ...      34             42            19        15
# 6      Atlético Madrid  ...      90             89            89         6
# 7      Manchester City  ...      59             53            29         6
# 8              Chelsea  ...      90             91            85        15
# 9             Juventus  ...      23             20            20         5
#
#   GKHandling  GKKicking  GKPositioning  GKReflexes Release Clause pozicija
# 0         11         15             14           8        €226.5M        N
# 1          9         15             15          11        €228.1M        N
# 2          9          7             14           9        €137.4M        V
# 3         25         31             33          37          €164M        N
# 4          8          9              7          11        €104.6M        B
# 5          6         12              8          10        €127.1M        N
# 6          8         15              5          15         €90.2M        B
# 7         15          7              6          12          €111M        V
# 8         12         10              7          10        €121.3M        V
# 9          4          4              5           8        €153.5M        N
#
# [10 rows x 90 columns]

# %%
sns.stripplot(x="pozicija",y="ST", data=df)

# %%
ax = sns.scatterplot(x="ShortPassing", y="Overall", hue="pozicija",data=df)

# %%
df_new = df[['pozicija',
'ShortPassing',
'Finishing',
'Overall','StandingTackle','Marking']]

sns.pairplot(df_new, kind="scatter", hue="pozicija",palette="husl") 
plt.show()

# %%
sns.stripplot(x="pozicija",y="SlidingTackle", data=df)

# %%
positions_names <- c("LS", "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM", "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB", "LCB", "CB", "RCB", "RB")
skills_names <- c("Crossing", "Finishing", "HeadingAccuracy", "ShortPassing", "Volleys", "Dribbling", "Curve", "FKAccuracy", "LongPassing", "BallControl", "Acceleration", "SprintSpeed", "Agility", "Reactions", "Balance", "ShotPower", "Jumping", "Stamina", "Strength", "LongShots", "Aggression", "Interceptions", "Positioning", "Vision", "Penalties", "Composure", "Marking", "StandingTackle", "SlidingTackle", "GKDiving", "GKHandling", "GKKicking", "GKPositioning", "GKReflexes")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b07f6b17b38e> in <module>
# ----> 1 positions_names <- c("LS", "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM", "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB", "LCB", "CB", "RCB", "RB")
#       2 skills_names <- c("Crossing", "Finishing", "HeadingAccuracy", "ShortPassing", "Volleys", "Dribbling", "Curve", "FKAccuracy", "LongPassing", "BallControl", "Acceleration", "SprintSpeed", "Agility", "Reactions", "Balance", "ShotPower", "Jumping", "Stamina", "Strength", "LongShots", "Aggression", "Interceptions", "Positioning", "Vision", "Penalties", "Composure", "Marking", "StandingTackle", "SlidingTackle", "GKDiving", "GKHandling", "GKKicking", "GKPositioning", "GKReflexes")
#
# NameError: name 'positions_names' is not defined

# %%
    import pandas as pd
    import numpy as np
    from sklearn.linear_model import LinearRegression
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import mean_squared_error, r2_score
    import matplotlib.pyplot as plt

# %%
    df = pd.read_csv('data/main_goalkeepers.csv')

# %%
df.plot(x='Overall', y='GKReflexes', style='o')  
plt.title('Overall vs GKReflexes')  
plt.xlabel('Overall')  
plt.ylabel('GKReflexes')  
plt.show()

# %%
df.plot(x='Overall', y='GKDiving', style='o')  
plt.title('Overall vs GKDiving')  
plt.xlabel('Overall')  
plt.ylabel('GKDiving')  
plt.show()

# %%
x = df.iloc[0 :100].values  
print(x) 
y= df.iloc
# Out:
# [[2 192119 'T. Courtois' ... 86 88 '€113.7M']
#  [3 167495 'M. Neuer' ... 87 87 '€62.7M']
#  [4 162835 'S. Handanovič' ... 89 89 '€51M']
#  ...
#  [97 187570 'Douglas' ... 74 77 '€4.4M']
#  [98 215223 'W. Benítez' ... 78 79 '€15.8M']
#  [99 140233 'G. Ochoa' ... 77 83 '€7.5M']]

# %%
# Out:
# [[0 200389 'J. Oblak' ... 78 88 89]
#  [1 192448 'M. ter Stegen' ... 88 85 90]
#  [2 192119 'T. Courtois' ... 72 86 88]
#  ...
#  [1617 53748 'K. Pilkington' ... 44 49 46]
#  [1618 245862 'J. Milli' ... 52 40 44]
#  [1619 242844 'J. Livesey' ... 58 42 48]]

# %%
def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1
    return float(out)

# %%
df['Value'] = df['Value'].apply(lambda x: extract_value_from(x))
df['Value'].head()
# Out:
# 0    110500.0
# 1    118500.0
# 2     67000.0
# 3     80000.0
# 4     51000.0
# Name: Value, dtype: float64

# %%
ax = sns.scatterplot(x="Overall", y="Value",hue="pozicija",data=df)

# %%
from scipy.stats import spearmanr

# %%
corr,p_value=spearmanr(df['Value'], df['Overall'])

# %%
print(corr)
# Out:
# 0.9160125153797644

# %%
sns.stripplot(x="pozicija",y="Value", data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d6415ff30418> in <module>
# ----> 1 sns.swarmplot(x="pozicija",y="Value", data=df)
#       2
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2975
#    2976     plotter = _SwarmPlotter(x, y, hue, data, order, hue_order,
# -> 2977                             dodge, orient, color, palette)
#    2978     if ax is None:
#    2979         ax = plt.gca()
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, dodge, orient, color, palette)
#    1212                  dodge, orient, color, palette):
#    1213         """Initialize the plotter."""
# -> 1214         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#    1215         self.establish_colors(color, palette, 1)
#    1216
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     156
#     157             # Figure out the plotting orientation
# --> 158             orient = self.infer_orient(x, y, orient)
#     159
#     160             # Option 2a:
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in infer_orient(self, x, y, orient)
#     359         elif is_not_numeric(y):
#     360             if is_not_numeric(x):
# --> 361                 raise ValueError(no_numeric)
#     362             else:
#     363                 return "h"
#
# ValueError: Neither the `x` nor `y` variable appears to be numeric.

# %%
sns.set(style="darkgrid")

g = sns.jointplot("Overall", "Value", data=df, kind="scatter",
                  xlim=(40, 100), ylim=(0, 120000), color="m", height=7)

# %%
g = sns.PairGrid(df)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter);
plt.show()

# %%
scipy.optimize.curve_fit(lambda t,a,b: a*numpy.exp(b*t),  df['Overall'],  df['Value'],  p0=(4, 0.1))
# Out:
# (array([0.01822379, 0.16937595]), array([[ 4.33381833e-07, -2.83440300e-07],
#         [-2.83440300e-07,  1.86493113e-07]]))

# %%
import scipy
import numpy
import pylab
import math

# %%
df.plot(x='Overall', y='Value', style='o')  
plt.title('Overall vs Value')  
plt.xlabel('Overall')  
plt.ylabel('Value')  

x = []
y = []
for i in range(0, 100):
    x.append(i)
    y.append(0.018*math.exp(0.1693*i))
plt.plot(x, y, 'r')
plt.show()

# %%
math.log(3)
# Out:
# 1.0986122886681098

# %%
df['Value']=math.log(df['Value'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ee06df54a36d> in <module>
# ----> 1 df['Value']=math.log(df['Value'])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'float'>
