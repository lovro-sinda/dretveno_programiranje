# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
from numpy import std
from scipy.stats import shapiro
from scipy.stats import normaltest
import numpy as np
import seaborn as sns

# %%
print("Dolje navedeni graf predstavlja vezu značajki BallControl i Overalla")
# Out:
# Dolje navedeni graf predstavlja vezu značajki BallControl i Overalla

# %%
DATA_LOCATION = "napad.csv"
FIRST_ATTRIBUTE = "ST"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")
data1.corr()
# Out:
#                ST   Overall
# ST       1.000000  0.968738
# Overall  0.968738  1.000000

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "Dribbling"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
print("Gore navedeni graf prikazuje linarnu vezu značajki Overall i Dribbling")
# Out:
# Gore navedeni graf prikazuje linarnu vezu značajki Overall i Dribbling

# %%
DATA_LOCATION = "players.csv"
FIRST_ATTRIBUTE = "FKAccuracy"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "FKAccuracy"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
print("Linearna veza značajki Overall i Composure")
# Out:
# Linearna veza značajki Overall i Composure

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "ShortPassing"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "LDM"
SECOND_ATTRIBUTE = "CDM"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
print("Linearna veza značajki CDM i LDM(jačina koju ima igrač kada je na mjestu centralnog i lijevog veznog)")
# Out:
# Linearna veza značajki CDM i LDM(jačina koju ima igrač kada je na mjestu centralnog i lijevog veznog)

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "LS"
SECOND_ATTRIBUTE = "ST"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "LW"
SECOND_ATTRIBUTE = "LF"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
print("Svaki igrač dobije bodove koje bi imao kada bi igrao na nekoj poziciji - pa su tako dvije napadačke pozicije LF I LW srodne")
# Out:
# Svaki igrač dobije bodove koje bi imao kada bi igrao na nekoj poziciji - pa su tako dvije napadačke pozicije LF I LW srodne

# %%
DATA_LOCATION = "main_goalkeepers.csv"
FIRST_ATTRIBUTE = "GKDiving"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
DATA_LOCATION = "main_goalkeepers.csv"
FIRST_ATTRIBUTE = "GKReflexes"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
print("Linearna veza Overalla vratara i njegovih refleksa")
# Out:
# Linearna veza Overalla vratara i njegovih refleksa

# %%
DATA_LOCATION = "main_goalkeepers.csv"
FIRST_ATTRIBUTE = "GKKicking"
SECOND_ATTRIBUTE = "Overall"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
print("Linearna veza Overalla i GKKickinga")
# Out:
# Linearna veza Overalla i GKKickinga

# %%
DATA_LOCATION = "main_goalkeepers.csv"
FIRST_ATTRIBUTE = "Crossing"
SECOND_ATTRIBUTE = "Finishing"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
datas.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  12946.000000   12946.000000  12946.000000  12946.000000  12946.000000
# mean    6472.500000  215238.597327     24.964004     66.444616     71.543488
# std     3737.332627   28612.744788      4.548840      6.797284      6.045304
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     3236.250000  201175.250000     21.000000     62.000000     67.000000
# 50%     6472.500000  222230.500000     25.000000     66.000000     71.000000
# 75%     9708.750000  236704.500000     28.000000     71.000000     75.000000
# max    12945.000000  246620.000000     41.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  12946.000000              12909.000000  12909.000000  12909.000000
# mean    1666.085973                  1.115268      3.005655      2.530947
# std      195.893456                  0.395834      0.635107      0.616683
# min     1000.000000                  1.000000      1.000000      1.000000
# 25%     1526.000000                  1.000000      3.000000      2.000000
# 50%     1668.000000                  1.000000      3.000000      2.000000
# 75%     1804.000000                  1.000000      3.000000      3.000000
# max     2346.000000                  5.000000      5.000000      5.000000
#
#        Jersey Number  ...     Penalties     Composure       Marking  \
# count   12897.000000  ...  12909.000000  12909.000000  12909.000000
# mean       19.350779  ...     52.118987     60.297002     51.304439
# std        15.607162  ...     12.528892     10.153010     17.222553
# min         2.000000  ...     13.000000     22.000000     10.000000
# 25%         8.000000  ...     42.000000     53.000000     37.000000
# 50%        17.000000  ...     52.000000     61.000000     56.000000
# 75%        25.000000  ...     62.000000     67.000000     65.000000
# max        99.000000  ...     92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    12909.000000   12909.000000  12909.000000  12909.000000
# mean        51.823457      49.592842     10.468433     10.562476
# std         19.213697      19.184122      3.106697      3.080433
# min         10.000000      10.000000      1.000000      1.000000
# 25%         35.000000      32.000000      8.000000      8.000000
# 50%         58.000000      56.000000     10.000000     11.000000
# 75%         67.000000      65.000000     13.000000     13.000000
# max         93.000000      91.000000     53.000000     48.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  12909.000000   12909.000000  12909.000000
# mean      10.552173      10.528856     10.526842
# std        3.149170       3.098858      3.131009
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       13.000000      13.000000     13.000000
# max       62.000000      57.000000     60.000000
#
# [8 rows x 70 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
from numpy import std
from scipy.stats import shapiro
from scipy.stats import normaltest
import numpy as np
import seaborn as sns
DATA_LOCATION = "croatia3.csv"
FIRST_ATTRIBUTE = "Overall"
SECOND_ATTRIBUTE = "Value"

datas = pd.read_csv(DATA_LOCATION)
data1 = datas[[FIRST_ATTRIBUTE, SECOND_ATTRIBUTE]]

sns.set(style="ticks")

rs = np.random.RandomState(11)
x = datas[FIRST_ATTRIBUTE]
y = datas[SECOND_ATTRIBUTE]


sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
from numpy import std
from scipy.stats import shapiro
from scipy.stats import normaltest
import numpy as np
import seaborn as sns
def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1
    return float(out)

# %%
DATA_LOCATION = "main_players.csv"

data = pd.read_csv(DATA_LOCATION)

# %%
data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
data['Value'].head()
# Out:
# 0    110500.0
# 1    118500.0
# 2     67000.0
# 3     80000.0
# 4     51000.0
# Name: Value, dtype: float64

# %%
data['Wage'].describe()
# Out:
# count     12929
# unique      140
# top         €1K
# freq       3271
# Name: Wage, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12929 entries, 0 to 12928
# Data columns (total 89 columns):
# Unnamed: 0                  12929 non-null int64
# ID                          12929 non-null int64
# Name                        12929 non-null object
# Age                         12929 non-null int64
# Photo                       12929 non-null object
# Nationality                 12929 non-null object
# Flag                        12928 non-null object
# Overall                     12929 non-null int64
# Potential                   12929 non-null int64
# Club                        12761 non-null object
# Club Logo                   12929 non-null object
# Value                       12929 non-null float64
# Wage                        12929 non-null object
# Special                     12929 non-null int64
# Preferred Foot              12892 non-null object
# International Reputation    12892 non-null float64
# Weak Foot                   12892 non-null float64
# Skill Moves                 12892 non-null float64
# Work Rate                   12892 non-null object
# Body Type                   12892 non-null object
# Real Face                   12892 non-null object
# Position                    12880 non-null object
# Jersey Number               12880 non-null float64
# Joined                      11790 non-null object
# Loaned From                 934 non-null object
# Contract Valid Until        12724 non-null object
# Height                      12892 non-null object
# Weight                      12892 non-null object
# LS                          12880 non-null float64
# ST                          12880 non-null float64
# RS                          12880 non-null float64
# LW                          12880 non-null float64
# LF                          12880 non-null float64
# CF                          12880 non-null float64
# RF                          12880 non-null float64
# RW                          12880 non-null float64
# LAM                         12880 non-null float64
# CAM                         12880 non-null float64
# RAM                         12880 non-null float64
# LM                          12880 non-null float64
# LCM                         12880 non-null float64
# CM                          12880 non-null float64
# RCM                         12880 non-null float64
# RM                          12880 non-null float64
# LWB                         12880 non-null float64
# LDM                         12880 non-null float64
# CDM                         12880 non-null float64
# RDM                         12880 non-null float64
# RWB                         12880 non-null float64
# LB                          12880 non-null float64
# LCB                         12880 non-null float64
# CB                          12880 non-null float64
# RCB                         12880 non-null float64
# RB                          12880 non-null float64
# Crossing                    12892 non-null float64
# Finishing                   12892 non-null float64
# HeadingAccuracy             12892 non-null float64
# ShortPassing                12892 non-null float64
# Volleys                     12892 non-null float64
# Dribbling                   12892 non-null float64
# Curve                       12892 non-null float64
# FKAccuracy                  12892 non-null float64
# LongPassing                 12892 non-null float64
# BallControl                 12892 non-null float64
# Acceleration                12892 non-null float64
# SprintSpeed                 12892 non-null float64
# Agility                     12892 non-null float64
# Reactions                   12892 non-null float64
# Balance                     12892 non-null float64
# ShotPower                   12892 non-null float64
# Jumping                     12892 non-null float64
# Stamina                     12892 non-null float64
# Strength                    12892 non-null float64
# LongShots                   12892 non-null float64
# Aggression                  12892 non-null float64
# Interceptions               12892 non-null float64
# Positioning                 12892 non-null float64
# Vision                      12892 non-null float64
# Penalties                   12892 non-null float64
# Composure                   12892 non-null float64
# Marking                     12892 non-null float64
# StandingTackle              12892 non-null float64
# SlidingTackle               12892 non-null float64
# GKDiving                    12892 non-null float64
# GKHandling                  12892 non-null float64
# GKKicking                   12892 non-null float64
# GKPositioning               12892 non-null float64
# GKReflexes                  12892 non-null float64
# Release Clause              11783 non-null object
# dtypes: float64(65), int64(6), object(18)
# memory usage: 8.8+ MB

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
from numpy import std
from scipy.stats import shapiro
from scipy.stats import normaltest
import numpy as np
import seaborn as sns
DATA_LOCATION = "main_players.csv"
FIRST_ATTRIBUTE = "Overall"
SECOND_ATTRIBUTE = "Value"


sns.set(style="ticks")

rs = np.random.RandomState(11)
x = data[FIRST_ATTRIBUTE]
y = data[SECOND_ATTRIBUTE]

sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
hist(data["Value"])
